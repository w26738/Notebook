# %% [markdown]
# ** Matplotlib 101 **

# %% [markdown]
# ### Basics

# %% [markdown]
# #### import matplotlib and see the version

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 2.2.2

# %% [markdown]
# #### import pyplot module and draw a curve

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

x = np.arange(100)
y = x * x

plt.plot(x, y)

# %% [markdown]
# #### plot multiple curves in one figure

# %%
x = np.linspace(-np.pi, np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# #### scatter plot

# %%
data = np.random.rand(2, 512)
print(data)
plt.scatter(data[0], data[1])
# Out:
# [[0.86760511 0.90209062 0.18350748 ... 0.60358233 0.5604269  0.03715261]
#  [0.21054758 0.70039379 0.42750359 ... 0.29184118 0.1313652  0.00773158]]

# %% [markdown]
# #### plot multiple bar charts

# %%
data = np.random.randint(0, 100, size=(3, 4))
x = np.arange(4)

plt.bar(x, data[0], color='r', width=0.25)
plt.bar(x+0.25, data[1], color='g', width=0.25)
plt.bar(x+0.5, data[2], color='b', width=0.25)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #### plot stack bar charts

# %%
data = np.random.randint(0, 100, size=(3, 4))
colors = ['r', 'g', 'b']
print(data)

rows = data.shape[0]
columns = np.arange(data.shape[1])
for row in range(rows):
    plt.bar(columns, data[row], bottom=np.sum(data[:row], axis=0), color=colors[row%len(colors)])
# Out:
# [[29 52 36 78]
#  [99 96 78 67]
#  [19 48 81  7]]

# %% [markdown]
# #### plot error bar

# %%
size = 10
x = np.linspace(-np.pi, np.pi, size)
y = np.sin(x) + np.random.random(size)

plt.errorbar(x, y, yerr=1, fmt='.r', capsize=5, capthick=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# #### plot area

# %%
x = range(1, 6)
y1 = [1, 4, 6, 8, 4]
y2 = [2, 4, 6, 8, 9]
plt.stackplot(x, y1, y2);

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area();
df.plot.area(stacked=False);
df.plot.area(alpha=0.35);
df.plot.area(stacked=False, alpha=0.35)

# %% [markdown]
# #### plot pie charts

# %%
labels = ['priority 1', 'priority 2', 'priority 3', 'priority 4']
colors = ['#996600', '#CCCC66', '#666600', '#CC3366']
fractions = [45, 30, 15, 10]
explode =(0, 0, 0, 0.05)
distance = 1.1

fig = plt.figure(figsize=(8,6))
plt.pie(fractions, explode=explode, colors=colors, labeldistance=distance, labels=None, 
        autopct='%1.1f%%', # add in percentages 
        startangle=90, shadow=False, 
        pctdistance=1.12 # the ratio between the center of each pie slice and the start of the text generated by autopct 
       )
plt.axis('equal')
plt.legend(labels, loc='upper left');

# %% [markdown]
# #### plot histograms

# %%
np.random.seed(100)
data = np.random.randn(1000)
kwargs = dict(alpha=0.5, color='blue', bins=20, edgecolor='black')

plt.hist(data, **kwargs)
# Out:
# (array([  4.,   3.,  11.,  26.,  36.,  75.,  86., 121., 137., 138., 105.,
#         108.,  69.,  36.,  21.,  10.,   7.,   3.,   3.,   1.]),
#  array([-3.20995538, -2.85656063, -2.50316588, -2.14977112, -1.79637637,
#         -1.44298162, -1.08958687, -0.73619211, -0.38279736, -0.02940261,
#          0.32399215,  0.6773869 ,  1.03078165,  1.3841764 ,  1.73757116,
#          2.09096591,  2.44436066,  2.79775542,  3.15115017,  3.50454492,
#          3.85793967]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #### plot Kernel-Density-Estimation (KDE)

# %%
import seaborn as sns

np.random.seed(100)
data = np.random.randn(1000)

sns.kdeplot(data)
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### plot boxplots

# %%
np.random.seed(100)
data = np.random.randn(1000, 4)

plt.boxplot(data, sym='',);

# %% [markdown]
# #### save figure to local

# %%
x = np.linspace(-np.pi, np.pi, 256)
y = np.tan(x)

plt.plot(x, y,)
# fig = plt.gcf()
# fig.set_size_inches(12, 8)
# # plt.savefig('tan.png', dip=1200, )
# # plt.savefig('tan.pdf', dip=900)

# %% [markdown]
# #### get and set plot style

# %%
print(matplotlib.get_configdir())
print(plt.style.available)
print(plt.rcParams)
# Out:
# C:\Users\anliu\.matplotlib
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']
# _internal.classic_mode: False
# agg.path.chunksize: 0
# animation.avconv_args: []
# animation.avconv_path: avconv
# animation.bitrate: -1
# animation.codec: h264
# animation.convert_args: []
# animation.convert_path: convert
# animation.embed_limit: 20.0
# animation.ffmpeg_args: []
# animation.ffmpeg_path: ffmpeg
# animation.frame_format: png
# animation.html: none
# animation.html_args: []
# animation.writer: ffmpeg
# axes.autolimit_mode: data
# axes.axisbelow: line
# axes.edgecolor: k
# axes.facecolor: w
# ...

# %%
# How do I omit matplotlib printed output in Python / Jupyter notebook? [duplicate]
# https://stackoverflow.com/questions/25790062/how-to-hide-matplotlib-lines-line2d-in-ipython-notebook?noredirect=1
inline_rc = dict(plt.rcParams)
plt.plot(range(10));

# %%
plt.style.use('ggplot')
plt.plot(range(10));

# %%
matplotlib.rcParams.update(inline_rc)
plt.plot(range(10));

# %% [markdown]
# ### Intermediate

# %% [markdown]
# #### creating a random scatter plot with points of many colors and sizes

# %%
data = np.random.random(size=(2,100))
colors = np.random.random(100)
size = 1000 * np.random.random(100)

# return a list of all registered colormaps
plt.colormaps()

plt.scatter(data[0], data[1], s=size, c=colors, alpha=0.25, cmap='winter')
plt.colorbar();

# %% [markdown]
# #### plot multiple subplot

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(234)
ax3 = fig.add_subplot(2,3,5)
ax4 = fig.add_subplot(2,3,6)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12,4))

axes[1,2].hist([1,1,2,3,7,5,5,6,1,2,3])
axes[0,1].hist([1,2,3,4,1]);

# %% [markdown]
# #### draw pmf curve of binomial distrubition with different parameters and add legend

# %%
from scipy import stats

paras = [(0.5, 20), (0.7, 20), (0.5, 40)]
colors = ['g', 'r', 'b']
markers = ['o', '^', 'x']
lss = ['--', '-.', ':']
labels = ['1', '2', '3']

fig = plt.figure()
ax = fig.add_subplot(111)
i = 0
for para in paras:
    binomal = stats.binom(para[1], para[0])
    binomal_pmf = binomal.pmf(np.arange(0, para[1]+1))
    ax.plot(binomal_pmf, ls=lss[i], marker = markers[i], color=colors[i], label=labels[i])
    i += 1
plt.xticks(rotation=-45)
ax.legend();

# %% [markdown]
# #### plot multiple columns of pandas dataframe

# %%
df = pd.DataFrame({'X_Axis':[1,3,5,7,10,20],
                   'col_2':[.4,.5,.4,.5,.5,.4],
                   'col_3':[.7,.8,.9,.4,.2,.3],
                   'col_4':[.1,.3,.5,.7,.1,.0],
                   'col_5':[.5,.3,.6,.9,.2,.4]})

df.plot(x='X_Axis', y=df.columns[1:5], figsize=(8,6))

# %% [markdown]
# #### format datetime in axis

# %%
# grouped_by_cell = data_iot.groupby('localMoid')
# fig = plt.figure(figsize=(16,30))
# n = len(grouped_by_cell)
# for i, (name, group) in enumerate(grouped_by_cell):
#     ax = fig.add_subplot(n, 1, i+1)
#     group.plot(x='Time', y=group.columns[3:14], ax=ax, title=name)    
#     days = mdates.DayLocator(interval=1)
#     hours = mdates.HourLocator(interval=3)
#     # 设置主刻度
#     ax.xaxis.set_major_locator(days)
#     # 设置副刻度
#     ax.xaxis.set_minor_locator(hours)
#     # 设置主刻度格式
#     ax.xaxis.set_major_formatter(mdates.DateFormatter('%D'))
#     # 设置副刻度格式
#     ax.xaxis.set_minor_formatter(mdates.DateFormatter('%H:%M'))
#     # 主副刻度标签间隔
#     ax.tick_params(pad=10)

# %% [markdown]
# #### put the legend out of the plot

# %%
# https://stackoverflow.com/questions/4700614/how-to-put-the-legend-out-of-the-plot?noredirect=1&lq=1
x = np.arange(10)

fig = plt.figure(figsize=(8,6))
ax = plt.subplot(111)

for i in range(5):
    line, = ax.plot(x, i * x, label='$y = %ix$'%i)

# Shrink current axis's height by 10% on the bottom
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
          fancybox=True, shadow=True, ncol=3)

# %% [markdown]
# #### set axis label's font/position/tick params

# %%
df = pd.DataFrame({'X_Axis':[1,3,5,7,10,20],
                   'col_2':[.4,.5,.4,.5,.5,.4],
                   'col_3':[.7,.8,.9,.4,.2,.3],
                   'col_4':[.1,.3,.5,.7,.1,.0],
                   'col_5':[.5,.3,.6,.9,.2,.4]})

ax = df.plot(x='X_Axis', y=df.columns[1:5], figsize=(8,6))
ax.set_xlabel('X', fontsize = 9)
ax.set_ylabel('Y', fontsize = 14)
ax.xaxis.set_label_coords(1.05, -0.025)

ax.legend(fontsize=14, loc='upper right')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelleft=False, left=False)
ax.set_title('Test', fontsize=16)

# Remove all borders
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
